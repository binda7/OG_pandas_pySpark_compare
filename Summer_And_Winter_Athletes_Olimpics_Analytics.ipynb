# %% [markdown]
# Reading Data - summer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
summer_athletes = pd.read_csv('Athletes_summer_games.csv', index_col=0)
winter_athletes = pd.read_csv('Athletes_winter_games.csv', index_col=0)

# %%
summer_athletes.head()
# Out:
#                                   Name Sex   Age            Team  NOC  \
# 0                            A Dijiang   M  24.0           China  CHN
# 1                             A Lamusi   M  23.0           China  CHN
# 2                  Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3                 Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands  NED
#
#           Games  Year  Season         City       Sport  \
# 0   1992 Summer  1992  Summer    Barcelona  Basketball
# 1   2012 Summer  2012  Summer       London        Judo
# 2   1920 Summer  1920  Summer    Antwerpen    Football
# 3   1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                            Event Medal
# 0    Basketball Men's Basketball   NaN
# 1   Judo Men's Extra-Lightweight   NaN
# 2        Football Men's Football   NaN
# 3    Tug-Of-War Men's Tug-Of-War  Gold
# 26  Athletics Women's 100 metres   NaN

# %%
winter_athletes.head()
# Out:
#                        Name Sex   Age         Team  NOC        Games  Year  \
# 4  Christine Jacoba Aaftink   F  21.0  Netherlands  NED  1988 Winter  1988
# 5  Christine Jacoba Aaftink   F  21.0  Netherlands  NED  1988 Winter  1988
# 6  Christine Jacoba Aaftink   F  25.0  Netherlands  NED  1992 Winter  1992
# 7  Christine Jacoba Aaftink   F  25.0  Netherlands  NED  1992 Winter  1992
# 8  Christine Jacoba Aaftink   F  27.0  Netherlands  NED  1994 Winter  1994
#
#    Season         City          Sport                               Event  \
# 4  Winter      Calgary  Speed Skating    Speed Skating Women's 500 metres
# 5  Winter      Calgary  Speed Skating  Speed Skating Women's 1,000 metres
# 6  Winter  Albertville  Speed Skating    Speed Skating Women's 500 metres
# 7  Winter  Albertville  Speed Skating  Speed Skating Women's 1,000 metres
# 8  Winter  Lillehammer  Speed Skating    Speed Skating Women's 500 metres
#
#   Medal
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN

# %%
# Zaplanowana analiza:
# Podział osób na płeć poniżej i powyżej średniej wieku
# Wyświetlić liczbę osób w zależności od lat, tak żeby podliczyć a następnie kilka box plot lub zwykły słupkowy
# Wyświetlić liczbę osób przeznaczoną na każdy kraj, w ddanym roku,
# Liczba osób biorących udział w igrzystach w danym mieście (suma)
# Wyświetlić jakiś wykres dyscyplin
# Medale zrobić wykres medali w zależności od lat, najlepiej od razu podział na złote, srebrne, brązowe na lata wielki wykres słupkowy, Wykluczyć NaN
# Wyświetlić listę zawodników z Polski i w jakich dyscyplinach brali udział oraz jakie zdobyte medale, podliczyć medale
# W jakiej dycyplinie brał udział najstarszy zawodnik a w jakiej najmłodszy ogółem
# Najmłodszy i najstarszy zawodnik w danym roku

# %%
summer_athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237673 entries, 0 to 15120
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    237673 non-null  object
#  1   Sex     237673 non-null  object
#  2   Age     228484 non-null  float64
#  3   Team    237673 non-null  object
#  4   NOC     237673 non-null  object
#  5   Games   237673 non-null  object
#  6   Year    237673 non-null  int64
#  7   Season  237673 non-null  object
#  8   City    237673 non-null  object
#  9   Sport   237673 non-null  object
#  10  Event   237673 non-null  object
#  11  Medal   36537 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 23.6+ MB

# %%
winter_athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48564 entries, 4 to 271115
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    48564 non-null  object
#  1   Sex     48564 non-null  object
#  2   Age     48279 non-null  float64
#  3   Team    48564 non-null  object
#  4   NOC     48564 non-null  object
#  5   Games   48564 non-null  object
#  6   Year    48564 non-null  int64
#  7   Season  48564 non-null  object
#  8   City    48564 non-null  object
#  9   Sport   48564 non-null  object
#  10  Event   48564 non-null  object
#  11  Medal   5695 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 4.8+ MB

# %%
print('summer_athletes shape:',summer_athletes.shape)
print('winter_athletes shape:', winter_athletes.shape)
# Out:
# summer_athletes shape: (237673, 12)
# winter_athletes shape: (48564, 12)

# %%
summer_athletes.describe()
# Out:
#                  Age           Year
# count  228484.000000  237673.000000
# mean       25.746267    1979.096246
# std         6.638720      31.783967
# min        10.000000    1896.000000
# 25%        21.000000    1960.000000
# 50%        25.000000    1988.000000
# 75%        29.000000    2004.000000
# max        97.000000    2020.000000

# %%
count_value_of_teams = summer_athletes['Team'].value_counts()
print(count_value_of_teams)
#To much number of Teams to plot everything so i plot first 20
count_value_of_teams.head(20).plot(kind='bar', figsize=(10,5))
# Out:
# United States         15382
# Great Britain         10857
# France                10559
# Italy                  8575
# Germany                7975
#                       ...
# Diabolo St Maurice        1
# Essen                     1
# Breslau                   1
# Hb-20                     1
# Rambo                     1
# Name: Team, Length: 1169, dtype: int64
# <AxesSubplot:>

# %%
count_value_of_teams = winter_athletes['Team'].value_counts()
print(count_value_of_teams)
#To much number of Teams to plot everything so i plot first 20
count_value_of_teams.head(20).plot(kind='bar', figsize=(10,5))
# Out:
# United States                  3321
# Canada                         2590
# Norway                         2328
# Sweden                         2231
# Italy                          2209
#                                ...
# Uruguay                           1
# Ghana                             1
# Individual Olympic Athletes       1
# Tonga                             1
# Paraguay                          1
# Name: Team, Length: 221, dtype: int64
# <AxesSubplot:>

# %%
summer_athletes['Age'].plot(kind='box', vert=False, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
winter_athletes['Age'].plot(kind='box', vert=False, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
ax = summer_athletes['Age'].plot(kind='density', figsize=(15,5))
ax.axvline(summer_athletes['Age'].mean(), color='red')
ax.axvline(summer_athletes['Age'].median(), color='green')

# %%
summer_athletes['Age'].mean()
# Out:
# 25.746266697011606

# %%
summer_athletes['Age'].median()
# Out:
# 25.0

# %%
summer_athletes['Age'].min()
# Out:
# 10.0

# %%
summer_athletes['Age'].max()
# Out:
# 97.0

# %%
summer_athletes['Age'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ax = winter_athletes['Age'].plot(kind='density', figsize=(15,5))
ax.axvline(winter_athletes['Age'].mean(), color='red')
ax.axvline(winter_athletes['Age'].median(), color='green')

# %%
winter_athletes['Age'].mean()
# Out:
# 25.0391474554154

# %%
winter_athletes['Age'].median()
# Out:
# 24.0

# %%
winter_athletes['Age'].min()
# Out:
# 11.0

# %%
winter_athletes['Age'].max()
# Out:
# 58.0

# %%
winter_athletes['Age'].plot(kind='hist')

# %%
corr = summer_athletes.corr() #Brak zgodności im bliżej jedynki tym lepiej, opisać jakoś otrzymane wyniki
corr
# Out:
#            Age      Year
# Age   1.000000 -0.106253
# Year -0.106253  1.000000

# %%
fig = plt.figure()
plt.matshow(corr, cmap='BrBG', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns)
plt.yticks(range(len(corr.columns)), corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x2069ccac430>,
#   <matplotlib.axis.YTick at 0x2069cc95c70>],
#  [Text(0, 0, 'Age'), Text(0, 1, 'Year')])

# %%
corr = winter_athletes.corr() #Brak zgodności im bliżej jedynki tym lepiej, opisać jakoś otrzymane wyniki
corr
# Out:
#            Age      Year
# Age   1.000000  0.056932
# Year  0.056932  1.000000

# %%
fig = plt.figure()
plt.matshow(corr, cmap='BrBG', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns)
plt.yticks(range(len(corr.columns)), corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x206a3907280>,
#   <matplotlib.axis.YTick at 0x206a38feac0>],
#  [Text(0, 0, 'Age'), Text(0, 1, 'Year')])

# %%
summer_athletes['Sex'].value_counts()
# Out:
# M    170964
# F     66709
# Name: Sex, dtype: int64

# %%
summer_athletes['Sex'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Sex'>
